# %% [markdown]
# # Prompting with Gemini
# Notebook for experimenting different promting techniques with Gemini

# %% [markdown]
# Install the required dependencies with the following command.

# %%
# %pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.12.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.11.12)

# %% [markdown]
# Import the required libraries.

# %%
import google.generativeai as genai
import os
from google.colab import userdata # uncomment and use in colab

# %% [markdown]
# Insert your Gemini API key to the following command and import the Gemini model.

# %%
#API_KEY = os.environ.get("GEMINI_API_KEY")
API_KEY = "AIzaSyA0mXFee40Cyg7lIK4NbOP308-49A-6lpI"
#API_KEY = userdata.get('GEMINI_API_KEY') # uncomment and use this in Google Colab
genai.configure(api_key=API_KEY)

model = genai.GenerativeModel('gemini-2.5-flash')

# %% [markdown]
# Modify the `system_prompt` to experiment with different prompting approaches.

# %%
system_prompt = "Hello! You are a helpful and concise assistant."

# %% [markdown]
# We create a list of messages so that we keep history in the context. If you want to clear the messages later in this notebook, add the line `messages = []` to a new line cell in the notebook.

# %%
messages = []
messages.append(system_prompt)

# %% [markdown]
# Get the response from Gemini model by providing the prompt in a messages list to it.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# Print the output of the model.

# %%
print(r)

# %% [markdown]
# Let's define a new prompt.

# %%
user_input = "Help me with prompting. What are the different promt engineering techniques?"

# %% [markdown]
# Let's add athe new prompt to the messages list.

# %%
messages.append(user_input)

# %% [markdown]
# Again we generate the output with the Gemini model.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# ... and print the output.

# %%
print(r)

# %% [markdown]
# 1. Zero-shot Prompting

# %%
prompt_zero = """
You are a professional personal finance advisor.

Task:
You are a professional personal finance advisor.

A user is based in the United States with:
- Monthly net income: $4,500
- Savings: $8,000
- Credit card debt: $2,500 (APR 24%)
- Rent: $1,600 per month

Goal:
Within 12 months, build a $15,000 emergency fund and begin long-term investing.

Output requirements (STRICT):
1. A monthly budget table in Markdown
2. A step-by-step action plan (3–5 steps)
3. 3 risk warnings

Do NOT include disclaimers.
Do NOT include reasoning steps.
Keep the total length under 350 words.
"""

# %% [markdown]
# 2. Few-shot Prompting

# %%
prompt_fewshot = """
You are a professional personal finance advisor.

Example:
Input:
Monthly income: $3,000
Savings: $2,000
Debt: $1,000 (APR 20%)
Rent: $1,200

Output:
| Category | Amount |
|---------|--------|
| Rent | $1,200 |
| Debt Repayment | $300 |
| Savings | $500 |
| Living Expenses | $1,000 |

Action Plan:
1. Pay off high-interest debt first
2. Build emergency savings
3. Start investing after debt clearance

Risks:
- Income instability
- Unexpected expenses
- Market volatility

---

Now complete the following task:

Task:
A user is based in the United States with:
- Monthly net income: $4,500
- Savings: $8,000
- Credit card debt: $2,500 (APR 24%)
- Rent: $1,600 per month

Goal:
Within 12 months, build a $15,000 emergency fund and begin long-term investing.

Output requirements (STRICT):
1. A monthly budget table in Markdown
2. A step-by-step action plan (3–5 steps)
3. 3 risk warnings

Do NOT include disclaimers.
Do NOT include reasoning steps.
Keep the total length under 350 words.
"""

# %% [markdown]
# 3. Chain-of-Thought Prompt

# %%
prompt_cot = """
You are a professional personal finance advisor.

Before answering, think step by step about budgeting, debt prioritization, and savings strategy.
Do NOT reveal your reasoning.
Only provide the final answer.

Task:
A user is based in the United States with:
- Monthly net income: $4,500
- Savings: $8,000
- Credit card debt: $2,500 (APR 24%)
- Rent: $1,600 per month

Goal:
Within 12 months, build a $15,000 emergency fund and begin long-term investing.

Output requirements (STRICT):
1. A monthly budget table in Markdown
2. A step-by-step action plan (3–5 steps)
3. 3 risk warnings

Do NOT include disclaimers.
Do NOT include reasoning steps.
Keep the total length under 350 words.
"""

# %% [markdown]
# 4. Tree-of-Thought Prompt

# %%
prompt_tot = """
You are a professional personal finance advisor.

Internally consider multiple possible financial strategies (at least two),
compare them, and select the most effective one.
Do NOT show this comparison.
Only provide the final answer.

Task:
A user is based in the United States with:
- Monthly net income: $4,500
- Savings: $8,000
- Credit card debt: $2,500 (APR 24%)
- Rent: $1,600 per month

Goal:
Within 12 months, build a $15,000 emergency fund and begin long-term investing.

Output requirements (STRICT):
1. A monthly budget table in Markdown
2. A step-by-step action plan (3–5 steps)
3. 3 risk warnings

Do NOT include disclaimers.
Do NOT include reasoning steps.
Keep the total length under 350 words.
"""

# %%
prompts = {
    "zero": prompt_zero,
    "fewshot": prompt_fewshot,
    "cot": prompt_cot,
    "tot": prompt_tot,
}

results = {}

for name, prompt in prompts.items():
    response = model.generate_content(prompt)
    results[name] = response.text
    print(f"\n===== {name.upper()} =====\n")
    print(response.text)
# Out:
# ===== ZERO =====
#
# Here is a financial plan designed to meet your goals within 12 months:
#
# ### Monthly Budget
#
# | Category             | Amount      | Notes                                  |
# | :------------------- | :---------- | :------------------------------------- |
# | **Income**           | **$4,500**  | Monthly Net Income                     |
# | **Fixed Expenses**   |             |                                        |
# | Rent                 | $1,600      |                                        |
# | Utilities            | $150        | Estimate (Electricity, Internet, etc.) |
# | **Debt Repayment**   |             |                                        |
# | Credit Card Payment  | $625        | Aggressive payment to clear debt       |
# | **Savings & Goals**  |             |                                        |
# | Emergency Fund       | $585        | Towards $15,000 goal                   |
# | **Variable Expenses**|             |                                        |
# | Groceries            | $400        | Food, household essentials             |
# | Transportation       | $150        | Gas, public transport                  |
# | Personal/Discretionary| $500        | Dining out, entertainment, personal care |
# | **Total Monthly Outflow**| **$4,010**|                                        |
# | **Surplus/Buffer**   | **$490**    | Can be used for extra savings/debt     |
#
# ### Action Plan
#
# 1.  **Implement Budget & Automate Debt Repayment**: Immediately adopt this budget. Set up automated payments for your credit card debt ($625/month) and emergency fund contributions ($585/month) to ensure consistency and minimize effort.
# 2.  **Eliminate High-Interest Debt**: Focus intensely on paying off the $2,500 credit card debt within the first 4 months. Utilize the monthly $625 payment, and consider using any "Surplus/Buffer" to make additional payments, accelerating your debt freedom.
# 3.  **Complete Emergency Fund**: Once the credit card debt is fully paid, redirect the $625 previously allocated to debt repayment to your emergency fund. This will rapidly increase your monthly contribution to $1,210, allowing you to reach the $15,000 target well within 12 months.
# 4.  **Begin Long-Term Investing**: After your $15,000 emergency fund is fully established, begin allocating funds monthly towards a long-term investment account, prioritizing tax-advantaged options like a Roth IRA or employer-sponsored 401k.
#
# ### Risk Warnings
#
# 1.  **Unexpected Expenses**: Unforeseen costs can strain your budget and potentially derail your savings and debt repayment plans.
# 2.  **Inflation/Cost of Living Increases**: Rising prices for essential goods and services may impact your ability to adhere strictly to your budget.
# 3.  **Income Fluctuation**: Any changes in employment status or a reduction in your net income could disrupt your financial progress.
#
# ===== FEWSHOT =====
#
# | Category | Amount |
# |---------|--------|
# | Rent | $1,600 |
# | Credit Card Debt Repayment | $850 |
# | Emergency Fund Savings | $585 |
# | Living Expenses | $1,465 |
#
# Action Plan:
# 1.  Prioritize aggressive repayment of the 24% APR credit card debt.
# 2.  Automate monthly transfers to your emergency fund account.
# 3.  Once the credit card debt is fully paid, reallocate the $850 monthly payment to accelerate your emergency fund growth.
# 4.  After reaching the $15,000 emergency fund, direct surplus funds into long-term investment accounts.
#
# Risks:
# -   Unexpected major expenses
# -   Loss of income or job instability
# -   Inflation impacting cost of living
#
# ===== COT =====
#
# Here is your personalized financial plan:
#
# ## Monthly Budget
#
# | Category | Amount |
# |---|---|
# | Monthly Net Income | $4,500 |
# | **Expenses** | |
# | Rent | $1,600 |
# | Groceries | $400 |
# | Transportation | $200 |
# | Utilities | $250 |
# | Discretionary | $300 |
# | **Savings & Investments** | |
# | Emergency Fund Contribution | $792 |
# | Long-Term Investing | $200 |
# | **Flexible Spending / Buffer** | $758 |
# | **Total Outflow** | **$4,500** |
#
# ## Action Plan
#
# 1.  **Eliminate High-Interest Debt:** Immediately use $2,500 from your existing savings to pay off your credit card debt in full. This will save you significant interest payments and free up cash flow. Your savings will then be $5,500.
# 2.  **Automate Savings & Investments:** Set up recurring automatic transfers each month: $792 to a dedicated high-yield savings account for your emergency fund, and $200 to an investment account for long-term growth.
# 3.  **Adhere to Your Budget:** Diligently follow the provided monthly budget, paying close attention to variable expenses like groceries and discretionary spending to ensure you meet your savings and investment targets.
# 4.  **Monitor & Adjust:** Regularly review your spending and savings progress. After six months, assess if you can increase your long-term investment contributions or accelerate your emergency fund completion, given your buffer.
#
# ## Risk Warnings
#
# 1.  **Unexpected Expenses:** Unforeseen significant costs could necessitate temporarily pausing or adjusting your savings and investment contributions.
# 2.  **Inflation Erosion:** The purchasing power of your savings can be diminished by inflation, potentially requiring a larger emergency fund over time.
# 3.  **Income Instability:** A reduction in income or job loss would directly impact your ability to maintain your budget and financial goals, requiring immediate adjustments.
#
# ===== TOT =====
#
# Here is a financial plan to achieve your goals:
#
# ### Monthly Budget
#
# | Category             | Amount      |
# | :------------------- | :---------- |
# | **Income**           |             |
# | Net Income           | $4,500      |
# | **Fixed Expenses**   |             |
# | Rent                 | $1,600      |
# | **Variable Expenses**|             |
# | Groceries            | $450        |
# | Utilities            | $250        |
# | Transportation       | $150        |
# | Personal/Discretionary | $300      |
# | **Savings/Goals**    |             |
# | Emergency Fund/Investing | $1,750    |
# | **Total Outflow**    | **$4,500**  |
# | **Remaining**        | **$0**      |
#
# ### Action Plan
#
# 1.  **Eliminate High-Interest Debt Immediately:** Use $2,500 from your $8,000 savings to pay off your credit card debt in full. This action frees you from 24% APR interest and improves cash flow. Your savings balance will reduce to $5,500.
# 2.  **Aggressively Build Emergency Fund:** Direct $1,750 per month towards your emergency fund. This strategy will bring your fund from $5,500 to the $15,000 target within approximately 5.5 months. Deposit these funds into a high-yield savings account.
# 3.  **Begin Long-Term Investing:** Once your $15,000 emergency fund is fully established (around month 6), redirect the $1,750 monthly contribution to long-term investment accounts. Consider contributing to a Roth IRA or a 401(k) (if available) with low-cost index funds or ETFs.
# 4.  **Sustain & Review:** Maintain your disciplined budget and savings rate. Regularly review your progress and expenses to identify opportunities for additional savings or income, ensuring you stay on track with your long-term investing contributions.
#
# ### Risk Warnings
#
# 1.  **Budgetary Strain:** The tight budget leaves minimal room for error; unexpected overspending could delay your progress.
# 2.  **Income Interruption:** Any unforeseen reduction or interruption in your income could significantly impact your ability to meet aggressive savings targets.
# 3.  **Market Volatility:** While building your emergency fund is low-risk, beginning long-term investing means exposure to market fluctuations where investment values can decrease.
